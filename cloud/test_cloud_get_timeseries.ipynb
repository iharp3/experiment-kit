# %%
from cloud_get_timeseries_executor import cloud_get_timeseries_executor

# %%
executor = cloud_get_timeseries_executor(
    variable="2m_temperature",  # Change to an available variable in the dataset
    start_datetime="2023-01-01",
    end_datetime="2023-01-10",
    temporal_resolution="hour",
    max_lat = 9,
    min_lat = 1,
    min_lon = 6,
    max_lon = 14,
    spatial_resolution=0.5,
    aggregation="max"
    )

# %%
results = executor.execute()

# %%
results
# Out:
# <xarray.DataArray '2m_temperature' (time: 240)> Size: 960B
# array([301.45987, 301.337  , 301.2915 , 301.27936, 301.24902, 301.25055,
#        301.2293 , 301.25208, 301.25812, 301.3719 , 305.33545, 307.72906,
#        308.61795, 309.23532, 310.22128, 310.07263, 310.2395 , 309.61908,
#        308.71353, 306.42456, 304.21146, 302.42612, 301.46594, 301.381  ,
#        301.3013 , 301.2387 , 301.12268, 301.1456 , 301.083  , 301.02805,
#        300.98224, 300.95325, 301.00665, 301.0662 , 304.82013, 306.30554,
#        307.7726 , 308.3451 , 309.22137, 308.87177, 308.78476, 308.92215,
#        309.35114, 307.82452, 306.36813, 304.92548, 301.657  , 300.91354,
#        300.81342, 300.7846 , 300.73456, 300.7755 , 300.8862 , 300.99994,
#        301.08942, 301.21527, 301.35327, 302.21765, 305.2142 , 306.14078,
#        308.40488, 308.93866, 309.2647 , 309.2192 , 309.28442, 308.3609 ,
#        307.64362, 306.2166 , 304.98676, 303.10327, 302.10242, 301.21832,
# ...
