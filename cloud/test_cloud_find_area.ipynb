# %%
from cloud_find_area_executor import cloud_find_area_executor

# %%
executor = cloud_find_area_executor(
    variable="2m_temperature",  # Change to an available variable in the dataset
    start_datetime="2023-01-01",
    end_datetime="2023-01-10",
    temporal_resolution="hour",
    max_lat = 9,
    min_lat = 1,
    min_lon = 6,
    max_lon = 14,
    spatial_resolution=0.5,
    aggregation="mean",
    filter_predicate= ">",  
    filter_value= 292.18628,
    )

# %%
result = executor.execute()

# %%
result
# Out:
# <xarray.Dataset> Size: 384B
# Dimensions:    (latitude: 16, longitude: 16)
# Coordinates:
#   * latitude   (latitude) float32 64B 8.875 8.375 7.875 ... 2.375 1.875 1.375
#   * longitude  (longitude) float32 64B 6.125 6.625 7.125 ... 12.62 13.12 13.62
# Data variables:
#     t2m        (latitude, longitude) bool 256B True True True ... True True True
